# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import os
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

# %%
# packages used by helper functions
import uuid

# %%
# packages for prompting definitions
import sys
sys.path.append("..")
import json

# %%
from langchain_community.llms import Ollama

# %%
import ollama
from ollama import Client
client = Client(host='http://192.168.178.39:11434')
modelo="gemma:latest"

# %% [markdown]
# ## Prompt definitions (function to extract triplets in JSON-format for knowledge graph from text chunks)

# %%
#################################
# Definition of used LLM
#################################
##########################################################################
def graphPrompt(input: str, metadata={}, model=modelo):
    if model == None:
        model = modelo
    
    chunk_id = metadata.get('chunk_id', None)

    # model_info = client.show(model_name=model)
    # print( chalk.blue(model_info))

    SYS_PROMPT = ("You are a network graph maker who extracts terms and their relations from a given context. "
        "You are provided with a context chunk (delimited by ```) Your task is to extract the ontology "
        "of terms mentioned in the given context. These terms should represent the key concepts as per the context. \n"
        "Thought 1: While traversing through each sentence, Think about the key terms mentioned in it.\n"
            "\tTerms may include Anforderung, requirement (AFO), rfc, organization, date, duration, \n"
            "\tcondition, concept, object, entity  etc.\n"
            "\tTerms should be as atomistic as possible\n\n"
        "Thought 2: Think about how these terms can have one on one relation with other terms.\n"
            "\tTerms that are mentioned in the same sentence or the same paragraph are typically related to each other.\n"
            "\tTerms can be related to many other terms\n\n"
        "Thought 3: Find out the relation between each such related pair of terms. \n\n"
        "Format your output as a list of json. Each element of the list contains a pair of terms"
        "and the relation between them like the follwing. NEVER change the value of the chunk_ID as defined in this prompt: \n"
        "[\n"
        "   {\n"
        '       "chunk_id": "CHUNK_ID_GOES_HERE",\n'
        '       "node_1": "A concept from extracted ontology",\n'
        '       "node_2": "A related concept from extracted ontology",\n'
        '       "edge": "relationship between the two concepts, node_1 and node_2 in one or two sentences"\n' 
        "   }, {...}\n"
        "]"
    )
    SYS_PROMPT = SYS_PROMPT.replace('CHUNK_ID_GOES_HERE', chunk_id)

    USER_PROMPT = f"context: ```{input}``` \n\n output: "

    response = client.generate(model=modelo, system=SYS_PROMPT, prompt=USER_PROMPT)

    aux1 = response['response']
    # Find the index of the first open bracket '['
    start_index = aux1.find('[')
    # Slice the string from start_index to extract the JSON part and fix an unexpected problem with insertes escapes (WHY ?)
    json_string = aux1[start_index:]
    json_string = json_string.replace('\\\\\_', '_')
    json_string = json_string.replace('\\\\_', '_')
    json_string = json_string.replace('\\\_', '_')
    json_string = json_string.replace('\\_', '_')
    json_string = json_string.replace('\_', '_')
    json_string.lstrip() # eliminate eventual leading blank spaces
#####################################################
    print("json-string:\n" + json_string)
#####################################################         
    try:
        result = json.loads(json_string)
        result = [dict(item) for item in result]
    except:
        print("\n\nERROR ### Here is the buggy response: ", response, "\n\n")
        result = None
    print("§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§")

    return result

# %% [markdown]
# ## Functions

# %%
def documents2Dataframe(documents) -> pd.DataFrame:
    rows = []
    for chunk in documents:
        row = {
            "text": chunk.page_content,
            **chunk.metadata,
            "chunk_id": uuid.uuid4().hex,
        }
        rows = rows + [row]

    df = pd.DataFrame(rows)
    return df

# %%
def df2Graph(dataframe: pd.DataFrame, model=None) -> list:
    # dataframe.reset_index(inplace=True)
    results = dataframe.apply(
        lambda row: graphPrompt(row.text, {"chunk_id": row.chunk_id}, model), axis=1
    )
    # invalid json results in NaN
    results = results.dropna()
    results = results.reset_index(drop=True)

    ## Flatten the list of lists to one single list of entities.
    concept_list = np.concatenate(results).ravel().tolist()
    return concept_list

# %% [markdown]
# def graph2Df(nodes_list) -> pd.DataFrame:
#     ## Remove all NaN entities
#     graph_dataframe = pd.DataFrame(nodes_list).replace(" ", np.nan)
#     graph_dataframe = graph_dataframe.dropna(subset=["node_1", "node_2"])
#     graph_dataframe["node_1"] = graph_dataframe["node_1"].apply(lambda x: x.lower())
#     graph_dataframe["node_2"] = graph_dataframe["node_2"].apply(lambda x: x.lower())
#
#     return graph_dataframe

# %%
def graph2Df(nodes_list) -> pd.DataFrame:
    # Erstellen des DataFrames aus der Knotenliste
    graph_dataframe = pd.DataFrame(nodes_list).replace(" ", np.nan)
    # Entfernen aller Zeilen, in denen 'node_1' oder 'node_2' NaN ist
    graph_dataframe = graph_dataframe.dropna(subset=["node_1", "node_2"])
    
    # Sicherstellen, dass 'node_1' und 'node_2' als Strings behandelt werden,
    # um den TypeError abzufangen
    graph_dataframe["node_1"] = graph_dataframe["node_1"].apply(lambda x: str(x).lower())
    graph_dataframe["node_2"] = graph_dataframe["node_2"].apply(lambda x: str(x).lower())

    return graph_dataframe

# %% [markdown]
# def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
#     ## Melt the dataframe into a list of nodes
#     dfg_long = pd.melt(
#         df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
#     )
#     dfg_long.drop(columns=["variable"], inplace=True)
#     # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
#     dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
#     # drop self loops
#     self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
#     dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
#     ## Group and count edges.
#     dfg2 = (
#         dfg2.groupby(["node_1", "node_2"])
#         .agg({"chunk_id": [",".join, "count"]})
#         .reset_index()
#     )
#     dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
#     dfg2.replace("", np.nan, inplace=True)
#     dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
#     # Drop edges with 1 count
#     dfg2 = dfg2[dfg2["count"] != 1]
#     dfg2["edge"] = "contextual proximity"
#     return dfg2

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    # Umwandlung des DataFrames
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    
    # Self-Join mit 'chunk_id' als Schlüssel
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    
    # Entfernung von Schleifen
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    
    # Stellen Sie sicher, dass 'chunk_id' als String behandelt wird
    dfg2["chunk_id"] = dfg2["chunk_id"].astype(str)
    
    # Gruppierung und Zählung von Kanten
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    
    # Entfernen von Kanten mit nur einem Vorkommen
    dfg2 = dfg2[dfg2["count"] > 1]
    dfg2["edge"] = "contextual proximity"
    
    return dfg2

# %% [markdown]
# ## Variables

# %%
import pdfplumber
## Input data directory
##########################################################
input_file_name = "gemSpec_VZD_V1.14.0.pdf"
##########################################################
data_dir = "./HotG_Data/"+input_file_name
inputdirectory = Path(f"./{data_dir+'.txt'}")

with pdfplumber.open(data_dir) as pdf:
    # Leeren String zum Speichern des Texts
    text = ''
    
    # Über alle Seiten iterieren
    for page in pdf.pages:
        # Text der aktuellen Seite extrahieren und an den Gesamttext anhängen
        text += page.extract_text()

# Text in eine TXT-Datei schreiben
with open(data_dir+'.txt', 'w', encoding='utf-8') as txt_file:
    txt_file.write(text)

## This is where the output csv files will be written
outputdirectory = Path(f"./data_output")

print(inputdirectory)
print(input_file_name)
# Out:
# HotG_Data/gemSpec_VZD_V1.14.0.pdf.txt
# gemSpec_VZD_V1.14.0.pdf

# %%
input_file_name=input_file_name+'.txt'
output_graph_file_name = f"graph_{input_file_name[:-4]}.csv"
output_graph_file_with_path = outputdirectory/output_graph_file_name

output_chunks_file_name = f"chunks_{input_file_name[:-4]}.csv"
output_chunks_file_with_path = outputdirectory/output_chunks_file_name

output_context_prox_file_name = f"graph_contex_prox_{input_file_name[:-4]}.csv"
output_context_prox_file_with_path = outputdirectory/output_context_prox_file_name

print(output_graph_file_with_path)
print(output_chunks_file_with_path)
print(output_context_prox_file_with_path)
# Out:
# data_output/graph_gemSpec_VZD_V1.14.0.pdf.csv
# data_output/chunks_gemSpec_VZD_V1.14.0.pdf.csv
# data_output/graph_contex_prox_gemSpec_VZD_V1.14.0.pdf.csv

# %% [markdown]
# ## Load Documents

# %%
#loader = TextLoader("./HotG_Data/Hanse.txt")
loader = TextLoader(inputdirectory)
Document = loader.load()
# clean unnecessary line breaks
Document[0].page_content = Document[0].page_content.replace("\n", " ")

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(Document)
print(Document[0])
Document2 = ''.join(str(item) for item in Document[0])
print(Document2)
from mattsollamatools import chunk_text_by_sentences
#pages = chunk_text_by_sentences(source_text=Document2, sentences_per_chunk=7, overlap=0 )

print("Number of chunks = ", len(pages))
print(pages[1].page_content)
# Out:
# page_content='Elektronische Gesundheitskarte und Telematikinfrastruktur Spezifikation Verzeichnisdienst Version: 1.14.0 Revision: 434138 Stand: 31.01.2022 Status: freigegeben Klassifizierung: öffentlich Referenzierung: gemSpec_VZD gemSpec_VZD_V1.docx Spezifikation Seite 1 von 72 Version: 1.14.0 © gematik – öffentlich Stand: 31.01.2022Spezifikation Verzeichnisdienst Dokumentinformationen Änderungen zur Vorversion Anpassungen des vorliegenden Dokumentes im Vergleich zur Vorversion können Sie der nachfolgenden Tabelle entnehmen. Bitte beachten Sie die Hinweise zur Einführung der Benennungen \'WANDA Basic\' und \'WANDA Smart\' (siehe Dokumentenhistorie). Dokumentenhistorie Version Stand Kap./ Grund der Änderung, besondere Hinweise Bearbeitung Seite 1.2.0 17.07.15 Nutzer der Schnittstelle gematik I_Directory_Maintenance geändert 1.3.0 24.08.16 Anpassungen zum Online-Produktivbetrieb gematik (Stufe 1) 1.4.0 28.10.16 Einarbeitung lt. Änderungsliste gematik 1.5.0 19.04.17 Anpassung nach Änderungsliste gematik 1.6.0 14.05.18 Anpassung nach Änderungslisten P15.2, 15.4 gematik und 15.5 1.7.0 15.05.19 Einarbeitung der Änderungen gemäß P18.1 gematik 1.8.0 28.06.19 Einarbeitung der Änderungen gemäß P19.1 gematik 1.9.0 02.10.19 Einarbeitung der Änderungen gemäß P20.1 gematik und P16.1/2 1.10.0 30.06.20 Anpassungen gemäß Änderungsliste P22.1 und gematik Scope-Themen aus Systemdesign R4.0.0 1.11.0 12.11.20 Anpassungen gemäß Änderungsliste P22.2 und gematik Scope-Themen aus Systemdesign R4.0.1 1.11.1 18.12.20 Einarbeitung der Änderungen gemäß P22.4 gematik 1.12.0 19.02.21 Anpassungen gemäß Änderungsliste P22.5; gematik Korrekturen in der Beschreibung des Datenmodells sowie neue Operation zur Abfrage aller Daten über die REST- Schnittstelle. 1.13.0 06.04.21 Anpassungen gemäß Änderungsliste gematik KIM_Maintenance_21.1/ KIM 1.5.1 gemSpec_VZD_V1.docx Spezifikation Seite 2 von 72 Version: 1.14.0 © gematik – öffentlich Stand: 31.01.2022Spezifikation Verzeichnisdienst 1.13.1 20.04.21 Anpassung C_10533 aus gematik KIM_Maintenance_21.1 vervollständigt (TIP1- A_5586 entfernt) 1.13.2 11.10.21 ab Release "Konnektor PTV 5.0.2: Maintenance gematik 21.5" (Sept. 2021) führt die gematik eine stufenweise Umbenennung folgender Begriffe durch: aus "aAdG-NetG" wird "WANDA Basic", aus "aAdG" und "aAdG-NetG-TI" wird "WANDA Smart" (nähere Informationen finden Sie unter https://fachportal.gematik.de/) 1.14.0 31.01.22 Anpassung gemäß Änderungsliste VZD- gematik Maintenance 21.1 (C_10737) und VZD- Maintenance 21.2 (C_10918) gemSpec_VZD_V1.docx Spezifikation Seite 3 von 72 Version: 1.14.0 © gematik – öffentlich Stand: 31.01.2022Spezifikation Verzeichnisdienst Inhaltsverzeichnis 1 Einordnung des Dokumentes ...................................................... 6 1.1 Zielsetzung ................................................................................................ 6 1.2 Zielgruppe ................................................................................................. 6 1.3 Geltungsbereich ........................................................................................ 6 1.4 Abgrenzungen ........................................................................................... 6 1.5 Methodik ................................................................................................... 7 2 Systemüberblick ......................................................................... 8 3 Übergreifende Festlegungen ....................................................... 9 3.1 IT-Sicherheit und Datenschutz .................................................................. 9 3.2 Fachliche Anforderungen ......................................................................... 10 4 Funktionsmerkmale .................................................................. 12 4.1 Schnittstelle I_Directory_Query .............................................................. 13 4.1.1 Operation search_Directory .................................................... ...
# ('page_content', 'Elektronische Gesundheitskarte und Telematikinfrastruktur Spezifikation Verzeichnisdienst Version: 1.14.0 Revision: 434138 Stand: 31.01.2022 Status: freigegeben Klassifizierung: öffentlich Referenzierung: gemSpec_VZD gemSpec_VZD_V1.docx Spezifikation Seite 1 von 72 Version: 1.14.0 © gematik – öffentlich Stand: 31.01.2022Spezifikation Verzeichnisdienst Dokumentinformationen Änderungen zur Vorversion Anpassungen des vorliegenden Dokumentes im Vergleich zur Vorversion können Sie der nachfolgenden Tabelle entnehmen. Bitte beachten Sie die Hinweise zur Einführung der Benennungen \'WANDA Basic\' und \'WANDA Smart\' (siehe Dokumentenhistorie). Dokumentenhistorie Version Stand Kap./ Grund der Änderung, besondere Hinweise Bearbeitung Seite 1.2.0 17.07.15 Nutzer der Schnittstelle gematik I_Directory_Maintenance geändert 1.3.0 24.08.16 Anpassungen zum Online-Produktivbetrieb gematik (Stufe 1) 1.4.0 28.10.16 Einarbeitung lt. Änderungsliste gematik 1.5.0 19.04.17 Anpassung nach Änderungsliste gematik 1.6.0 14.05.18 Anpassung nach Änderungslisten P15.2, 15.4 gematik und 15.5 1.7.0 15.05.19 Einarbeitung der Änderungen gemäß P18.1 gematik 1.8.0 28.06.19 Einarbeitung der Änderungen gemäß P19.1 gematik 1.9.0 02.10.19 Einarbeitung der Änderungen gemäß P20.1 gematik und P16.1/2 1.10.0 30.06.20 Anpassungen gemäß Änderungsliste P22.1 und gematik Scope-Themen aus Systemdesign R4.0.0 1.11.0 12.11.20 Anpassungen gemäß Änderungsliste P22.2 und gematik Scope-Themen aus Systemdesign R4.0.1 1.11.1 18.12.20 Einarbeitung der Änderungen gemäß P22.4 gematik 1.12.0 19.02.21 Anpassungen gemäß Änderungsliste P22.5; gematik Korrekturen in der Beschreibung des Datenmodells sowie neue Operation zur Abfrage aller Daten über die REST- Schnittstelle. 1.13.0 06.04.21 Anpassungen gemäß Änderungsliste gematik KIM_Maintenance_21.1/ KIM 1.5.1 gemSpec_VZD_V1.docx Spezifikation Seite 2 von 72 Version: 1.14.0 © gematik – öffentlich Stand: 31.01.2022Spezifikation Verzeichnisdienst 1.13.1 20.04.21 Anpassung C_10533 aus gematik KIM_Maintenance_21.1 vervollständigt (TIP1- A_5586 entfernt) 1.13.2 11.10.21 ab Release "Konnektor PTV 5.0.2: Maintenance gematik 21.5" (Sept. 2021) führt die gematik eine stufenweise Umbenennung folgender Begriffe durch: aus "aAdG-NetG" wird "WANDA Basic", aus "aAdG" und "aAdG-NetG-TI" wird "WANDA Smart" (nähere Informationen finden Sie unter https://fachportal.gematik.de/) 1.14.0 31.01.22 Anpassung gemäß Änderungsliste VZD- gematik Maintenance 21.1 (C_10737) und VZD- Maintenance 21.2 (C_10918) gemSpec_VZD_V1.docx Spezifikation Seite 3 von 72 Version: 1.14.0 © gematik – öffentlich Stand: 31.01.2022Spezifikation Verzeichnisdienst Inhaltsverzeichnis 1 Einordnung des Dokumentes ...................................................... 6 1.1 Zielsetzung ................................................................................................ 6 1.2 Zielgruppe ................................................................................................. 6 1.3 Geltungsbereich ........................................................................................ 6 1.4 Abgrenzungen ........................................................................................... 6 1.5 Methodik ................................................................................................... 7 2 Systemüberblick ......................................................................... 8 3 Übergreifende Festlegungen ....................................................... 9 3.1 IT-Sicherheit und Datenschutz .................................................................. 9 3.2 Fachliche Anforderungen ......................................................................... 10 4 Funktionsmerkmale .................................................................. 12 4.1 Schnittstelle I_Directory_Query .............................................................. 13 4.1.1 Operation search_Directory ................................................ ...
# Number of chunks =  308
# zur Vorversion können Sie der nachfolgenden Tabelle entnehmen. Bitte beachten Sie die Hinweise zur Einführung der Benennungen 'WANDA Basic' und 'WANDA Smart' (siehe Dokumentenhistorie). Dokumentenhistorie Version Stand Kap./ Grund der Änderung, besondere Hinweise Bearbeitung Seite 1.2.0 17.07.15 Nutzer der Schnittstelle gematik I_Directory_Maintenance geändert 1.3.0 24.08.16 Anpassungen zum Online-Produktivbetrieb gematik (Stufe 1) 1.4.0 28.10.16 Einarbeitung lt. Änderungsliste gematik 1.5.0

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (308, 3)
#                                                 text  \
# 0  Elektronische Gesundheitskarte und Telematikin...
# 1  zur Vorversion können Sie der nachfolgenden Ta...
# 2  Einarbeitung lt. Änderungsliste gematik 1.5.0 ...
# 3  aus Systemdesign R4.0.0 1.11.0 12.11.20 Anpass...
# 4  KIM 1.5.1 gemSpec_VZD_V1.docx Spezifikation Se...
#
#                                   source                          chunk_id
# 0  HotG_Data/gemSpec_VZD_V1.14.0.pdf.txt  1b42cf2e35834b15be1b92a83f65586e
# 1  HotG_Data/gemSpec_VZD_V1.14.0.pdf.txt  982090fa14804745a97e241d19d33a4f
# 2  HotG_Data/gemSpec_VZD_V1.14.0.pdf.txt  187f305ecd93445689fccaae2ef93846
# 3  HotG_Data/gemSpec_VZD_V1.14.0.pdf.txt  17652a6a484d4c51a036e59dceadaea7
# 4  HotG_Data/gemSpec_VZD_V1.14.0.pdf.txt  178f90cc581c492cae72eac890c1e661

# %% [markdown]
# ## Extract Concepts

# %%
## To regenerate the graph with LLM, set this to True
##################
regenerate = True  # toggle to True if the time-consuming (re-)generation of the knowlege extraction is required
##################
if regenerate:
#########################################################    
    concepts_list = df2Graph(df, model=modelo)
#########################################################
    dfg1 = graph2Df(concepts_list)
    
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(output_graph_file_with_path, sep=";", index=False)
    df.to_csv(output_chunks_file_with_path, sep=";", index=False)
else:
    dfg1 = pd.read_csv(output_graph_file_with_path, sep=";")

dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head()
# Out:
# json-string:
# [
#    {
#        "chunk_id": "1b42cf2e35834b15be1b92a83f65586e",
#        "node_1": "Elektronische Gesundheitskarte",
#        "node_2": "Telematikinfrastruktur",
#        "edge": "Verzeichnisdienst Version: 1.14.0"
#    },
#    {
#        "chunk_id": "1b42cf2e35834b15be1b92a83f65586e",
#        "node_1": "Verzeichnisdienst",
#        "node_2": "Version: 1.14.0",
#        "edge": "Revision: 434138 Stand: 31.01.2022"
#    },
#    {
#        "chunk_id": "1b42cf2e35834b15be1b92a83f65586e",
#        "node_1": "Version: 1.14.0",
#        "node_2": "Stand: 31.01.2022",
#        "edge": "Status: freigegeben Klassifizierung: öffentlich"
#    },
#    {
#        "chunk_id": "1b42cf2e35834b15be1b92a83f65586e",
#        "node_1": "Klassifizierung: öffentlich",
#        "node_2": "Referenzierung: gemSpec_VZD gemSpec_VZD_V1.docx",
#        "edge": "Spezifikation Seite 1 von 72"
#    }
# ]
# ```
#
# **Explanation:**
#
# * The extracted terms from the context are "Elektronische Gesundheitskarte", "Telematikinfrastruktur", "Verzeichnisdienst", "Version", "Stand", "Status", "Klassifizierung", and "Referenzierung".
# * The relations between these terms are shown in the "edge" field of each element in the json list.
# * Each pair of terms and their relation is extracted from the sentences in the context that mention both terms.
# * The "chunk_id" field is included to maintain the integrity of the extracted data.
#
#
# ERROR ### Here is the buggy response:  {'model': 'gemma:latest', 'created_at': '2024-04-08T20:02:08.9726534Z', 'response': '```json\n[\n   {\n       "chunk_id": "1b42cf2e35834b15be1b92a83f65586e",\n       "node_1": "Elektronische Gesundheitskarte",\n       "node_2": "Telematikinfrastruktur",\n       "edge": "Verzeichnisdienst Version: 1.14.0"\n   },\n   {\n       "chunk_id": "1b42cf2e35834b15be1b92a83f65586e",\n       "node_1": "Verzeichnisdienst",\n       "node_2": "Version: 1.14.0",\n       "edge": "Revision: 434138 Stand: 31.01.2022"\n   },\n   {\n       "chunk_id": "1b42cf2e35834b15be1b92a83f65586e",\n       "node_1": "Version: 1.14.0",\n       "node_2": "Stand: 31.01.2022",\n       "edge": "Status: freigegeben Klassifizierung: öffentlich"\n   },\n   {\n       "chunk_id": "1b42cf2e35834b15be1b92a83f65586e",\n       "node_1": "Klassifizierung: öffentlich",\n       "node_2": "Referenzierung: gemSpec_VZD gemSpec_VZD_V1.docx",\n       "edge": "Spezifikation Seite 1 von 72"\n   }\n]\n```\n\n**Explanation:**\n\n* The extracted terms from the context are "Elektronische Gesundheitskarte", "Telematikinfrastruktur", "Verzeichnisdienst", "Version", "Stand", "Status", "Klassifizierung", and "Referenzierung".\n* The relations between these terms are shown in the "edge" field of each element in the json list.\n* Each pair of terms and their relation is extracted from the sentences in the context that mention both terms.\n* The "chunk_id" field is included to maintain the integrity of the extracted data.', 'done': True, 'context': [106, 1645, 108, 2045, 708, 476, 6011, 5989, 27493, 1064, 46143, 4563, 578, 1024, 4106, 774, 476, 2764, 4807, 235265, 1646, 708
n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```\n```', 'done': True, 'context': [106, 1645, 108, 2045, 708, 476, 6011, 5989, 27493, 1064, 46143, 4 ...
#
#
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
# {
# "chunk_id": "178f90cc581c492cae72eac890c1e661",
# "node_1": "A concept from extracted ontology",
# "node_2": "A related concept from extracted ontology",
# "edge": "relationship between the two concepts, node_1 and node_2 in one oder zwei sentences"
# }, {...}
# ] context: ```KIM 1.5.1 gemSpec_VZD_V1.docx Spezifikation Seite 2 von 72 Version: 1.14.0 © gematik –
#
#
# ERROR ### Here is the buggy response:  {'model': 'gemma:latest', 'created_at': '2024-04-08T20:02:57.9268173Z', 'response': '```\n[\n{\n"chunk_id": "178f90cc581c492cae72eac890c1e661",\n"node_1": "A concept from extracted ontology",\n"node_2": "A related concept from extracted ontology",\n"edge": "relationship between the two concepts, node_1 and node_2 in one oder zwei sentences"\n}, {...}\n] context: ```KIM 1.5.1 gemSpec_VZD_V1.docx Spezifikation Seite 2 von 72 Version: 1.14.0 © gematik –', 'done': True, 'context': [106, 1645, 108, 2045, 708, 476, 6011, 5989, 27493, 1064, 46143, 4563, 578, 1024, 4106, 774, 476, 2764, 4807, 235265, 1646, 708, 4646, 675, 476, 4807, 34657, 591, 495, 16174, 731, 24424, 235275, 3883, 6911, 603, 577, 16787, 573, 126064, 576, 4563, 8248, 575, 573, 2764, 4807, 235265, 3766, 4563, 1412, 4319, 573, 2621, 17482, 685, 842, 573, 4807, 235265, 235248, 108, 65366, 235248, 235274, 235292, 7859, 162330, 1593, 1853, 13060, 235269, 24174, 1105, 573, 2621, 4563, 8248, 575, 665, 235265, 108, 226, 31694, 1249, 3707, 1364, 92698, 235269, 17008, 591, 235280, 5716, 823, 548, 11886, 235269, 8344, 235269, 3209, 235269, 14827, 235269, 235248, 108, 226, 15079, 235269, 7819, 235269, 4018, 235269, 12395, 139, 15893, 235265, 108, 226, 31694, 1412, 614, 685, 35954, 109244, 685, 3077, 109, 65366, 235248, 235284, 235292, 24174, 1105, 1368, 1450, 4563, 798, 791, 974, 611, 974, 10189, 675, 1156, 4563, 235265, 108, 226, 31694, 674, 708, 8248, 575, 573, 1809, 13060, 689, 573, 1809, 16957, 708, 15976, 5678, 577, 1853, 1156, 235265, 108, 226, 31694, 798, 614, 5678, 577, 1767, 1156, 4563, 109, 65366, 235248, 235304, 235292, 8682, 921, 573, 10189, 1865, 1853, 1582, 5678, 8537, 576, 4563, 235265, 235248, 109, 5699, 861, 5033, 685, 476, 1889, 576, 6772, 235265, 9573, 5356, 576, 573, 1889, 7744, 476, 8537, 576, 4563, 639, 573, 10189, 1865, 1174, 1154, 573, 137733, 9483, 235265, 59946, 2669, 573, 1618, 576, 573, 34657, 235298, 1342, 685, 6908, 575, 736, 18335, 235292, 235248, 108, 235309, 108, 140, 235282, 108, 144, 235281, 31763, 235298, 539, 1192, 664, 235274, 235324, 235321, 235266, 235315, 235276, 830, 235308, 235321, 235274, 235260, 235310, 235315, 235284, 143810, 235324, 235284, 191821, 235321, 235315, 235276, 235260, 235274, 235249, 235318, 235318, 235274, 824, 108, 144, 235281, 3937, 235298, 235274, 1192, 664, 235280, 7819, 774, 33378, 126064, 824, 108, 144, 235281, 3937, 235298, 235284, 1192, 664, 235280, 5678, 7819, 774, 33378, 126064, 824, 108, 144, 235281, 9926, 1192, 664, 62633, 1865, 573, 1378, 17482, 235269, 5705, 235298, 235274, 578, 5705, 235298, 235284, 575, 974, 689, 1378, 26099, 235281, 108, 140, 789, 54487, 235270, 108, 235307, 4807, 235292, 24424, 140345, 235248, 235274, 235265, 235308, 235265, 235274, 21737, 4823, 235298, 235330, 105391, 235298, 235330, 235274, 235265, 32961, 172257, 82754, 25156, 235248, 235284, 2232, 235248, 235324, 235284, 11036, 235292, 235248, 235274, 235265, 235274, 235310, 235265, 235276, 11532, 21737, 18787, 1157, 162331, 6674, 235292, 235248, 235304, 235274, 235265, 235276, 235274, 235265, 235284, 235276, 235284, 235284, 132678, 82754, 2466, 78056, 40178, 235248, 235274, 235265, 235274, 235304, 235265, 235274, 235248, 235284, 235276, 235265, 235276, 235310, 235265, 235284, 235274, 163717, 1063, 585, 235298, 235274, 235276, 235308, 235304, 235304, 2918, 21737, 18787, 126993, 235298, 54061, 235298, 235284, 235274, 235265, 235274, 41766, 32640, 21398, 15278, 591, 43566, 235274, 235290, 586, 235298, 235308, 235308, 235321, 235318, 64530, 235275, 235248, 235274, 235265, 235274, 235304, 235265, 235284, 235248, 235274, 235274, 235265, 235274, 235276, 235265, 235284, 235274, 841, 16185, 664, 16095, 510, 13364, 596, 8952, 235248, 235308, 235265, 235276, 235265, 235284, 235292, 29107, 21737, 18787, 235248, 235284, 235274, 235265, 235308, 235281, 591, 47536, 235265, 235248, 235284, 235276, 235284, 235274, 235275, 54190, 1303, 21737, 18787, 3994, 680, 17907, 11068, 55221, 479, 188628, 105607, 112677, 66 ...
#
#
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
# {
# "chunk_id": "d39b78c098074b74967eebe782d2149e",
# "node_1": "A concept from extracted ontology",
# "node_2": "A related concept from extracted ontology",
# "edge": "relationship between the two concepts, node_1 and node_2 in one oder zwei sentences"
# }, {...}
# ]
# context: ```aus "aAdG" und "aAdG-NetG-TI" wird "WANDA Smart" (nähere Informationen finden Sie unter https://fachportal.gematik.de/) 1.14.0 31.01.22 Anpassung gemäß Änderungsliste VZD- gematik Maintenance 21.1 (C_10737) und VZD- Maintenance 21.2 (C_10918) gemSpec_VZD_V1.docx Spezifikation Seite 3 von 72 Version: 1.14.0 © gematik – öffentlich Stand: 31.01.2022Spezifikation Verzeichnisdienst Inhaltsverzeichnis 1 Einordnung des Documentes ...................................................... 6 1.1 Zielsetzung```
# ```
#
# ```
# [
# {
# "chunk_id": "d39b78c098074b74967eebe782d2149e",
# "node_1": "A concept from extracted ontology",
# "node_2": "A related concept from extracted ontology",
# "edge": "Relationship between the two concepts, node_1 und node_2 in one oder zwei sentences"
# }, {...}
# ]
# context: ```aus "aAdG" und "aAdG-NetG-TI" wird "WANDA Smart" (nähere Informationen finden Sie unter https://fachportal.gematik.de/) 1.14.0 31.01.22 Anpassung gemäß Änderungsliste VZD- gematik Maintenance 21.1 (C_10737) und VZD- Maintenance 21.2 (C_10918) gemSpec_VZD_V1.docx Spezifikation Seite 3 von 72 Version: 1.14.0 © gematik – öffentlich Stand: 31.01.2022Spezifikation Verzeichnisdienst Inhaltsverzeichnis 1 Einordnung des Documentes ...................................................... 6 1.1 Ziel
#
#
# ERROR ### Here is the buggy response:  {'model': 'gemma:latest', 'created_at': '2024-04-08T20:03:10.3809726Z', 'response': '```\n[\n{\n"chunk_id": "d39b78c098074b74967eebe782d2149e",\n"node_1": "A concept from extracted ontology",\n"node_2": "A related concept from extracted ontology",\n"edge": "relationship between the two concepts, node_1 and node_2 in one oder zwei sentences"\n}, {...}\n]\ncontext: ```aus "aAdG" und "aAdG-NetG-TI" wird "WANDA Smart" (nähere Informationen finden Sie unter https://fachportal.gematik.de/) 1.14.0 31.01.22 Anpassung gemäß Änderungsliste VZD- gematik Maintenance 21.1 (C_10737) und VZD- Maintenance 21.2 (C_10918) gemSpec_VZD_V1.docx Spezifikation Seite 3 von 72 Version: 1.14.0 © gematik – öffentlich Stand: 31.01.2022Spezifikation Verzeichnisdienst Inhaltsverzeichnis 1 Einordnung des Documentes ...................................................... 6 1.1 Zielsetzung```\n```\n\n```\n[\n{\n"chunk_id": "d39b78c098074b74967eebe782d2149e",\n"node_1": "A concept from extracted ontology",\n"node_2": "A related concept from extracted ontology",\n"edge": "Relationship between the two concepts, node_1 und node_2 in one oder zwei sentences"\n}, {...}\n]\ncontext: ```aus "aAdG" und "aAdG-NetG-TI" wird "WANDA Smart" (nähere Informationen finden Sie unter https://fachportal.gematik.de/) 1.14.0 31.01.22 Anpassung gemäß Änderungsliste VZD- gematik Maintenance 21.1 (C_10737) und VZD- Maintenance 21.2 (C_10918) gemSpec_VZD_V1.docx Spezifikation Seite 3 von 72 Version: 1.14.0 © gematik – öffentlich Stand: 31.01.2022Spezifikation Verzeichnisdienst Inhaltsverzeichnis 1 Einordnung des Documentes ...................................................... 6 1.1 Ziel', 'done': True, 'context': [106, 1645, 108, 2045, 708, 476, 6011, 5989, 27493, 1064, 46143, 4563, 578, 1024, 4106, 774, 476, 2764, 4807, 235265, 1646, 708, 4646, 675, 476, 4807, 34657, 591, 495, 16174, 731, 24424, 235275, 3883, 6911, 603, 577, 16787, 573, 126064, 576, 4563, 8248, 575, 573, 2764, 4807, 235265, 3766, 4563, 1412, 4319, 573, 2621, 17482, 685, 842, 573, 4807, 235265, 235248, 108, 65366, 235248, 235274, 235292, 7859, 162330, 1593, 1853, 13060, 235269, 24174, 1105, 573, 2621, 4563, 8248, 575, 665, 235265, 108, 226, 31694, 1249, 3707, 1364, 92698, 235269, 17008, 591, 235280, 5716, 823, 548, 11886, 235269, 8344, 235269, 3209, 235269, 14827, 235269, 235248, 108, 226, 15079, 235269, 7819, 235269, 4018, 235269, 12395, 139, 15893, 235265, 108, 226, 31694, 1412, 614, 685, 35954, 109244, 685, 3077, 109, 65366, 235248, 235284, 235292, 24174, 1105, 1368, 1450, 4563, 798, 791, 974, 611, 974, 10189, 675, 1156, 4563, 235265, 108, 226, 31694, 674, 708, 8248, 575, 573, 1809, 13060, 689, 573, 1809, 16957, 708, 15976, 5678, 577, 1853, 1156, 235265, 108, 226, 31694, 798, 614, 5678, 577, 1767, 1156, 4563, 109, 65366, 235248, 235304, 235292, 8682, 921, 573, 10189, 1865, 1853, 1582, 5678, 8537, 576, 4563, 235265, 235248, 109, 5699, 861, 5033, 685, 476, 1889, 576, 6772, 235265, 9573, 5356, 576, 573, 1889, 7744, 476, 8537, 576, 4563, 639, 573, 10189, 1865, 1174, 1154, 573, 137733, 9483, 235265, 59946, 2669, 573, 1618, 576, 573, 34657, 235298, 1342, 685, 6908, 575, 736, 18335, 235292, 235248, 108, 235309, 108, 140, 235282, 108, 144, 235281, 31763, 235298, 539, 1192, 664, 235258, 235304, 235315, 235268, 235324, 235321, 235260, 235276, 235315, 235321, 235276, 235324, 235310, 235268, 235324, 235310, 235315, 235318, 235324, 1537, 555, 235324, 235321, 235284, 235258, 235284, 235274, 235310, 235315, 235249, 824, 108, 144, 235281, 3937, 235298, 235274, 1192, 664, 235280, 7819, 774, 33378, 126064, 824, 108, 144, 235281, 3937, 235298, 235284, 1192, 664, 235280, 5678, 7819, 774, 33378, 126064, 824, 108, 144, 235281, 9926, 1192, 664, 62633, 1865, 573, 1378, 17482, 235269, 5705, 235298, 235274, 578, 5705, 235298, 235284, 575, 974, 689, 1378, 26099, 235281, 108, 140, 789, 54487, 235270, 108, 235307, 4807, 235292, 24424, 10487, 664, 235250, 1441, 235319, 235281, 930, 664, 235250, 1441, 23531 ...
#
#
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#    {
#        "chunk_id": "a06f04f3a4414b2e9eb0844770f05302",
#        "node_1": "A concept from extracted ontology",
#        "node_2": "A related concept from extracted ontology",
#        "edge": "relationship between the two concepts, node_1 and node_2 in one or deux sentences"
#    }, {...}
# ] context: ```6 1.1 Zielsetzung ................................................................................................................ 6 1.2 Zielgruppe ................................................................................................. 6 1.3 Geltung payee ................................................................................................
#
#
# ERROR ### Here is the buggy response:  {'model': 'gemma:latest', 'created_at': '2024-04-08T20:03:14.9798353Z', 'response': '```\n[\n   {\n       "chunk_id": "a06f04f3a4414b2e9eb0844770f05302",\n       "node_1": "A concept from extracted ontology",\n       "node_2": "A related concept from extracted ontology",\n       "edge": "relationship between the two concepts, node_1 and node_2 in one or deux sentences"\n   }, {...}\n] context: ```6 1.1 Zielsetzung ................................................................................................................ 6 1.2 Zielgruppe ................................................................................................. 6 1.3 Geltung payee ................................................................................................', 'done': True, 'context': [106, 1645, 108, 2045, 708, 476, 6011, 5989, 27493, 1064, 46143, 4563, 578, 1024, 4106, 774, 476, 2764, 4807, 235265, 1646, 708, 4646, 675, 476, 4807, 34657, 591, 495, 16174, 731, 24424, 235275, 3883, 6911, 603, 577, 16787, 573, 126064, 576, 4563, 8248, 575, 573, 2764, 4807, 235265, 3766, 4563, 1412, 4319, 573, 2621, 17482, 685, 842, 573, 4807, 235265, 235248, 108, 65366, 235248, 235274, 235292, 7859, 162330, 1593, 1853, 13060, 235269, 24174,
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#    {
#        "chunk_id": "4005effbbb70497182dfef97ba4c8990",
#        "node_1": "A concept từ extracted ontology",
#        "node_2": "A related concept từ extracted ontology",
#        "edge": "Relationship entre nod_1 e nod_2 em uma ou duassentences"
#    }, {...}
# ]
#
# context: ```6 1.5 Methodik ................................................................................................... 7 2 Systemüberblick ......................................................................... 8 3 Übergreifende Festlegungen ....................................................... 9 3.1 IT-Sicherheit und Datenschutz ................................................................... 9 3.2 Fachliche Requirements
#
#
# ERROR ### Here is the buggy response:  {'model': 'gemma:latest', 'created_at': '2024-04-08T20:03:18.8832897Z', 'response': '```\n[\n   {\n       "chunk_id": "4005effbbb70497182dfef97ba4c8990",\n       "node_1": "A concept từ extracted ontology",\n       "node_2": "A related concept từ extracted ontology",\n       "edge": "Relationship entre nod_1 e nod_2 em uma ou duassentences"\n   }, {...}\n]\n\ncontext: ```6 1.5 Methodik ................................................................................................... 7 2 Systemüberblick ......................................................................... 8 3 Übergreifende Festlegungen ....................................................... 9 3.1 IT-Sicherheit und Datenschutz ................................................................... 9 3.2 Fachliche Requirements', 'done': True, 'context': [106, 1645, 108, 2045, 708, 476, 6011, 5989, 27493, 1064, 46143, 4563, 578, 1024, 4106, 774, 476, 2764, 4807, 235265, 1646, 708, 4646, 675, 476, 4807, 34657, 591, 495, 16174, 731, 24424, 235275, 3883, 6911, 603, 577, 16787, 573, 126064, 576, 4563, 8248, 575, 573, 2764, 4807, 235265, 3766, 4563, 1412, 4319, 573, 2621, 17482, 685, 842, 573, 4807, 235265, 235248, 108, 65366, 235248, 235274, 235292, 7859, 162330, 1593, 1853, 13060, 235269, 24174, 1105, 573, 2621, 4563, 8248, 575, 665, 235265, 108, 226, 31694, 1249, 3707, 1364, 92698, 235269, 17008, 591, 235280, 5716, 823, 548, 11886, 235269, 8344, 235269, 3209, 235269, 14827, 235269, 235248, 108, 226, 15079, 235269, 7819, 235269, 4018, 235269, 12395, 139, 15893, 235265, 108, 226, 31694, 1412, 614, 685, 35954, 109244, 685, 3077, 109, 65366, 235248, 235284, 235292, 24174, 1105, 1368, 1450, 4563, 798, 791, 974, 611, 974, 10189, 675, 1156, 4563, 235265, 108, 226, 31694, 674, 708, 8248, 575, 573, 1809, 13060, 689, 573, 1809, 16957, 708, 15976, 5678, 577, 1853, 1156, 235265, 108, 226, 31694, 798, 614, 5678, 577, 1767, 1156, 4563, 109, 65366, 235248, 235304, 235292, 8682, 921, 573, 10189, 1865, 1853, 1582, 5678, 8537, 576, 4563, 235265, 235248, 109, 5699, 861, 5033, 685, 476, 1889, 576, 6772, 235265, 9573, 5356, 576, 573, 1889, 7744, 476, 8537, 576, 4563, 639, 573, 10189, 1865, 1174, 1154, 573, 137733, 9483, 235265, 59946, 2669, 573, 1618, 576, 573, 34657, 235298, 1342, 685, 6908, 575, 736, 18335, 235292, 235248, 108, 235309, 108, 140, 235282, 108, 144, 235281, 31763, 235298, 539, 1192, 664, 235310, 235276, 235276, 235308, 10171, 93398, 235324, 235276, 235310, 235315, 235324, 235274, 235321, 235284, 3442, 1029, 235315, 235324, 2070, 235310, 235260, 235321, 235315, 235315, 235276, 824, 108, 144, 235281, 3937, 235298, 235274, 1192, 664, 235280, 7819, 774, 33378, 126064, 824, 108, 144, 235281, 3937, 235298, 235284, 1192, 664, 235280, 5678, 7819, 774, 33378, 126064, 824, 108, 144, 235281, 9926, 1192, 664, 62633, 1865, 573, 1378, 17482, 235269, 5705, 235298, 235274, 578, 5705, 235298, 235284, 575, 974, 689, 1378, 26099, 235281, 108, 140, 789, 54487, 235270, 108, 235307, 4807, 235292, 24424, 235318, 235248, 235274, 235265, 235308, 47578, 19886, 235248, 5519, 5519, 5519, 5519, 5519, 5519, 955, 235248, 235324, 235248, 235284, 1479, 16680, 27843, 235248, 5519, 5519, 5519, 5519, 25984, 235248, 235321, 235248, 235304, 16490, 131571, 4365, 34861, 209204, 235248, 5519, 5519, 5519, 18546, 235248, 235315, 235248, 235304, 235265, 235274, 6349, 235290, 226442, 930, 97516, 235248, 5519, 5519, 5519, 5519, 723, 235248, 235315, 235248, 235304, 235265, 235284, 41719, 6842, 104916, 1917, 235248, 109, 5033, 235292, 235248, 107, 108, 106, 2516, 108, 1917, 108, 235309, 108, 140, 235282, 108, 144, 235281, 31763, 235298, 539, 1192, 664, 235310, 235276, 235276, 235308, 10171, 93398, 235324, 235276, 235310, 235315, 235324, 235274, 235321, 235284, 3442, 1029, 235315, 235324, 2070, 235310, 235260, 235321, 235315, 235315, 235276, 824, 108, 144, 235281, 3937, 235298, 235274, 1192, 664, 235280, 7819, 15997, 33378, 126064, 824, 108, 144, 235281, 3937, 235298, 235284, 119 ...
#
#
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#    {
#        "chunk_id": "7e7b7bfee82b4b39a17dc24055af5182",
#        "node_1": "A concept from extracted ontology",
#        "node_2": "A related concept from extracted ontology",
#        "edge": "relationship between the two concepts, node_1 and node_2 in one or two sentences"
#    }, {...}
# ]
# ```
#
#  context: ```9 3.2 Fachliche Anforderungen ......................................................................................... 10 4 Funktions feats ................................................................... 12 4.1 Schnittstelle I_Directory_Query .....................................................................14 4.1.1 Operation search_Directory .....................................................................14 4.1.1.1 Schnittstelle I_Directory_Query ................................................................................... 13 4.1.1 Operation search_Directory .....................................................................14 4.1.1.1 Schnittstelle I_Directory_Query ................................................................................... 10 4 Schnittstelle I_Directory_Query ................................................................................... 14 4.1.1.1 Schnittstelle I_Directory_Query ................................................................................... 13 4.1.1 Schnittstelle I_Directory_Query ................................................................................... 14 4.1.1.1 Schnittstelle I_Directory_Query ................................................................................... 14 4.1.1.1 Schnittstelle I_Directory_Query ................................................................................... 10 4 Schnittstelle I_Directory_Query ................................................................................................... 10 4 Schnittstelle I_Directory_Query ................................................................................................... 14 4.1.1.1 Schnittstelle I_Directory_Query ................................................................................................... 13 4.1.1 Schnittstelle I_Directory_Query ................................................................................................... 14 4.1.1.1 Schnittstelle I_Directory_Query ...................................................................................................
# ```
#
#
# ERROR ### Here is the buggy response:  {'model': 'gemma:latest', 'created_at': '2024-04-08T20:03:29.7415013Z', 'response': '```\n[\n   {\n       "chunk_id": "7e7b7bfee82b4b39a17dc24055af5182",\n       "node_1": "A concept from extracted ontology",\n       "node_2": "A related concept from extracted ontology",\n       "edge": "relationship between the two concepts, node_1 and node_2 in one or two sentences"\n   }, {...}\n]\n```\n\n context: ```9 3.2 Fachliche Anforderungen ......................................................................................... 10 4 Funktions feats ................................................................... 12 4.1 Schnittstelle I_Directory_Query .....................................................................14 4.1.1 Operation search_Directory .....................................................................14 4.1.1.1 Schnittstelle I_Directory_Query ................................................................................... 13 4.1.1 Operation search_Directory .....................................................................14 4.1.1.1 Schnittstelle I_Directory_Query ................................................................................... 10 4 Schnittstelle I_Directory_Query ................................................................................... 14 4.1.1.1 Schnittstelle I_Directory_Query ................................................................................... 13 4.1.1 Schnittstelle I_Directory_Query ................................................................................... 14 4.1.1.1 Schnittstelle I_Directory_Query ................................................................................... 14 4.1.1.1 Schnittstelle I_Directory_Query ................................................................................... 10 4 Schnittstelle I_Directory_Query ................................................................................................... 10 4 Schnittstelle I_Directory_Query ................................................................................................... 14 4.1.1.1 Schnittstelle I_Directory_Query ................................................................................................... 13 4.1.1 Schnittstelle I_Directory_Query ................................................................................................... 14 4.1.1.1 Schnittstelle I_Directory_Query ...................................................................................................\n```', 'done': True, 'context': [106, 1645, 108, 2045, 708, 476, 6011, 5989, 27493, 1064, 46143, 4563, 578, 1024, 4106, 774, 476, 2764, 4807, 235265, 1646, 708, 4646, 675, 476, 4807, 34657, 591, 495, 16174, 731, 24424, 235275, 3883, 6911, 603, 577, 16787, 573, 126064, 576, 4563, 8248, 575, 573, 2764, 4807, 235265, 3766, 4563, 1412, 4319, 573, 2621, 17482, 685, 842, 573, 4807, 235265, 235248, 108, 65366, 235248, 235274, 235292, 7859, 162330, 1593, 1853, 13060, 235269, 24174, 1105, 573, 2621, 4563, 8248, 575, 665, 235265, 108, 226, 31694, 1249, 3707, 1364, 92698, 235269, 17008, 591, 235280, 5716, 823, 548, 11886, 235269, 8344, 235269, 3209, 235269, 14827, 235269, 235248, 108, 226, 15079, 235269, 7819, 235269, 4018, 235269, 12395, 139, 15893, 235265, 108, 226, 31694, 1412, 614, 685, 35954, 109244, 685, 3077, 109, 65366, 235248, 235284, 235292, 24174, 1105, 1368, 1450, 4563, 798, 791, 974, 611, 974, 10189, 675, 1156, 4563, 235265, 108, 226, 31694, 674, 708, 8248, 575, 573, 1809, 13060, 689, 573, 1809, 16957, 708, 15976, 5678, 577, 1853, 1156, 235265, 108, 226, 31694, 798, 614, 5678, 577, 1767, 1156, 4563, 109, 65366, 235248, 235304, 235292, 8682, 921, 573, 10189, 1865, 1853, 1582, 5678, 8537, 576, 4563, 235265, 235248, 109, 5699, 861, 5033, 685, 476, 1889, 576, 6772, 235265, 9573, 5356, 576, 573, 1889, 7744, 476, 8537, 576, 4563, 639, 573, 10189, 1865, 1174, 1154, 573, 137733, 9483, 235265, 59946, 2669, 573, 1618, 576, 573,  ...
#
#
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#    {
#        "chunk_id": "536d3e12b90f490fae5005be2cbec066",
#        "node_1": "A concept from extracted ontology",
#        "node_2": "A related concept from extracted ontology",
#        "edge": "relationship between the two concepts, node_1 and node_2 in one or deux sentences"
#    }, {...}
# ] context: ```4.1.1.1.1 Umsetzung ......................................................................................14 4.1.1.2 Nutzung ..........................................................................................15 4.2 Schnittstelle I_Directory_Maintenance .................................................... 15 4.2.1 Operation add_Directory_Entry ................................................................16 4.2.1.1
# ]
#
# ```
#
# ```
# [
#    {
#        "chunk_id": "536d3e12b90f490fae5005be2cbec066",
#        "node_1": "A concept extracted ontology",
#        "node_2": "A related concept extracted ontology",
#        "edge": "relationship between the two concepts, node_1 và node_2 in one or deux sentences"
#    }, {...}
# ] context: ```4.1.1.1.1.1 Umsetzung ......................................................................................14 4.1.1.2 Nutzung ..........................................................................................15 4.2 Schnittstelle I_Directory_Maintenance .................................................... 15 4.2.1.1
# ]
#
# ```
#
# ```
#
# [
#    {
#        "chunk_id": "536d3e12b90f490fae5005be2cbec066",
#        "node_1": "A concept extracted ontology",
#        "node_2": "A related concept extracted ontology",
#        "edge": "relationship between the two concepts, node_1 và node_2 in one or deux sentences"
#    }, {...}
# ] context: ```4.1.1.1.1.1
#
#
# ...
#
# ```
# [
#    {
#        "chunk_id": "bae30832528a4fe9ac6b74a7ebd71d01",
#        "node_1": "A concept extracted ontology",
#        "node_2": "A related concept from extracted ontology",
#        "edge": "relationship between the two concepts, node_1 và node_2 in one or two sentences"
#    }, {...}
# ] context: ```Access Protocol (LDAP): String Representation of Distinguished Names http://www.rfc-editor.org/rfc/rfc4515.txt [RFC4 RFC 4516 (June 2006): 515] Lightweight Directory Access Protocol (LDAP): String Representation of Search Filters http://www.rfc-editor.org/rfc/rfc4515.txt [RFC4 RFC 4517 (June 2006): 517] Lightweight Directory Access Protocol (LDAP): Uniform Resource Locator http://www.rfc-editor.org/rfc/rfc4516.txt [RFC4 RFC 4517 (June 2006): 517] Lightweight Directory Access Protocol (LDAP):```
#
#
# ERROR ### Here is the buggy response:  {'model': 'gemma:latest', 'created_at': '2024-04-08T20:44:27.6133749Z', 'response': '```\n[\n   {\n       "chunk_id": "bae30832528a4fe9ac6b74a7ebd71d01",\n       "node_1": "A concept from extracted ontology",\n       "node_2": "A related concept from extracted ontology",\n       "edge": "relationship between the two concepts, node_1 and node_2 in one or two sentences"\n   }, {...}\n] context: ```Access Protocol (LDAP): String Representation of Distinguished Names http://www.rfc-editor.org/rfc/rfc4515.txt [RFC4 RFC 4516 (June 2006): 515] Lightweight Directory Access Protocol (LDAP): String Representation of Search Filters http://www.rfc-editor.org/rfc/rfc4515.txt [RFC4 RFC 4517 (June 2006): 517] Lightweight Directory Access Protocol (LDAP): Uniform Resource Locator http://www.rfc-editor.org/rfc/rfc4516.txt [RFC4 RFC 4517 (June 2006): 517] Lightweight Directory Access Protocol (LDAP):```\n\n```\n[\n   {\n       "chunk_id": "bae30832528a4fe9ac6b74a7ebd71d01",\n       "node_1": "A concept extracted ontology",\n       "node_2": "A related concept from extracted ontology",\n       "edge": "relationship between the two concepts, node_1 và node_2 in một or two sentences"\n   }, {...}\n] context: ```Access Protocol (LDAP): String Representation of Distinguished Names http://www.rfc-editor.org/rfc/rfc4515.txt [RFC4 RFC 4516 (June 2006): 515] Lightweight Directory Access Protocol (LDAP): String Representation of Search Filters http://www.rfc-editor.org/rfc/rfc4515.txt [RFC4 RFC 4517 (June 2006): 517] Lightweight Directory Access Protocol (LDAP): Uniform Resource Locator http://www.rfc-editor.org/rfc/rfc4516.txt [RFC4 RFC 4517 (June 2006): 517] Lightweight Directory Access Protocol (LDAP):```\n\n```\n[\n   {\n       "chunk_id": "bae30832528a4fe9ac6b74a7ebd71d01",\n       "node_1": "A concept extracted ontology",\n       "node_2": "A related concept from extracted ontology",\n       "edge": "relationship between the two concepts, node_1 và node_2 in one or two sentences"\n   }, {...}\n] context: ```Access Protocol (LDAP): String Representation of Distinguished Names http://www.rfc-editor.org/rfc/rfc4515.txt [RFC4 RFC 4516 (June 2006): 515] Lightweight Directory Access Protocol (LDAP): String Representation of Search Filters http://www.rfc-editor.org/rfc/rfc4515.txt [RFC4 RFC 4517 (June 2006): 517] Lightweight Directory Access Protocol (LDAP): Uniform Resource Locator http://www.rfc-editor.org/rfc/rfc4516.txt [RFC4 RFC 4517 (June 2006): 517] Lightweight Directory Access Protocol (LDAP):```', 'done': True, 'context': [106, 1645, 108, 2045, 708, 476, 6011, 5989, 27493, 1064, 46143, 4563, 578, 1024, 4106, 774, 476, 2764, 4807, 235265, 1646, 708, 4646, 675, 476, 4807, 34657, 591, 495, 16174, 731, 24424, 235275, 3883, 6911, 603, 577, 16787, 573, 126064, 576, 4563, 8248, 575, 573, 2764, 4807, 235265, 3766, 4563, 1412, 4319, 573, 2621, 17482, 685, 842, 573, 4807, 235265, 235248, 108, 65366, 235248, 235274, 235292, 7859, 162330, 1593, 1853, 13060, 235269, 24174, 1105, 573, 2621, 4563, 8248, 575, 665, 235265, 108, 226, 31694, 1249, 3707, 1364, 92698, 235269, 17008, 591, 235280, 5716, 823, 548, 11886, 235269, 8344, 235269, 3209, 235269, 14827, 235269, 235248, 108, 226, 15079, 235269, 7819, 235269, 4018, 235269, 12395, 139, 15893, 235265, 108, 226, 31694, 1412, 614, 685, 35954, 109244, 685, 3077, 109, 65366, 235248, 235284, 235292, 24174, 1105, 1368, 1450, 4563, 798, 791, 974, 611, 974, 10189, 675, 1156, 4563, 235265, 108, 226, 31694, 674, 708, 8248, 575, 573, 1809, 13060, 689, 573, 1809, 16957, 708, 15976, 5678, 577, 1853, 1156, 235265, 108, 226, 31694, 798, 614, 5678, 577, 1767, 1156, 4563, 109, 65366, 235248, 235304, 235292, 8682, 921, 573, 10189, 1865, 1853, 1582, 5678, 8537, 576, 4563, 235265, 235248, 109, 5699, 861, 5033, 685, 476, 1889, 576, 6772, 235265, 9573, 5356, 576, 573, 1889, 7744, 476, 8537, 576, 4563, 639, 573, 10189, 1865, 1174, 1154, 573, 137733, 9483, 235265, 59946, 2669, 573, 1618, 576, 573, 3 ...
#
#
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# json-string:
# [
#    {
#        "chunk_id": "88e7ab9c85d449908c9a4a20bd1d5a13",
#        "node_1": "A concept from extracted ontology",
#        "node_2": "A related concept from extracted ontology",
#        "edge": "relationship between the two concepts, node_1 and node_2 in one or two sentences"
#    }, {...}
# ] context: ```Lightweight Directory Access Protocol (LDAP): Syntaxeses and Matching Rules http://www.rfc-editor.org/rfc/rfc4519.txt [RFC4 RFC 4519 (June 2006): 519] Lightweight Directory Access Protocol (LDAP): Schema for User Applications http://www.rfc-editor.org/rfc/rfc4519.txt [RFC4 RFC 4522 (June 2006): 522] Lightweight Directory Access Protocol (LDAP): The Binary Encoding Option http://www.rfc-editor.org/rfc/rfc4522.txt [RFC4 RFC 4523 (June 2006): 523] Lightweight Directory Access Protocol (LDAP) Schema```
#
# ```
# [
#    {
#        "chunk_id": "88e7ab9c85d449908c9a4a20bd1d5a13",
#        "node_1": "A concept from extracted ontology",
#        "node_2": "A related concept from extracted ontology",
#        "edge": "relationship between the two concepts, node_1 and node_2 in one or two sentences"
#    }, {...}
# ] context: ```Lightweight Directory Access Protocol (LDAP): Syntaxeses
#
#
# ERROR ### Here is the buggy response:  {'model': 'gemma:latest', 'created_at': '2024-04-08T20:44:36.4792742Z', 'response': '```\n[\n   {\n       "chunk_id": "88e7ab9c85d449908c9a4a20bd1d5a13",\n       "node_1": "A concept from extracted ontology",\n       "node_2": "A related concept from extracted ontology",\n       "edge": "relationship between the two concepts, node_1 and node_2 in one or two sentences"\n   }, {...}\n] context: ```Lightweight Directory Access Protocol (LDAP): Syntaxeses and Matching Rules http://www.rfc-editor.org/rfc/rfc4519.txt [RFC4 RFC 4519 (June 2006): 519] Lightweight Directory Access Protocol (LDAP): Schema for User Applications http://www.rfc-editor.org/rfc/rfc4519.txt [RFC4 RFC 4522 (June 2006): 522] Lightweight Directory Access Protocol (LDAP): The Binary Encoding Option http://www.rfc-editor.org/rfc/rfc4522.txt [RFC4 RFC 4523 (June 2006): 523] Lightweight Directory Access Protocol (LDAP) Schema```\n\n```\n[\n   {\n       "chunk_id": "88e7ab9c85d449908c9a4a20bd1d5a13",\n       "node_1": "A concept from extracted ontology",\n       "node_2": "A related concept from extracted ontology",\n       "edge": "relationship between the two concepts, node_1 and node_2 in one or two sentences"\n   }, {...}\n] context: ```Lightweight Directory Access Protocol (LDAP): Syntaxeses', 'done': True, 'context': [106, 1645, 108, 2045, 708, 476, 6011, 5989, 27493, 1064, 46143, 4563, 578, 1024, 4106, 774, 476, 2764, 4807, 235265, 1646, 708, 4646, 675, 476, 4807, 34657, 591, 495, 16174, 731, 24424, 235275, 3883, 6911, 603, 577, 16787, 573, 126064, 576, 4563, 8248, 575, 573, 2764, 4807, 235265, 3766, 4563, 1412, 4319, 573, 2621, 17482, 685, 842, 573, 4807, 235265, 235248, 108, 65366, 235248, 235274, 235292, 7859, 162330, 1593, 1853, 13060, 235269, 24174, 1105, 573, 2621, 4563, 8248, 575, 665, 235265, 108, 226, 31694, 1249, 3707, 1364, 92698, 235269, 17008, 591, 235280, 5716, 823, 548, 11886, 235269, 8344, 235269, 3209, 235269, 14827, 235269, 235248, 108, 226, 15079, 235269, 7819, 235269, 4018, 235269, 12395, 139, 
689, 1378, 26099, 235281, 108, 140, 789, 54487, 235270, 108, 235307, 4807, 235292, 24424, 18945, 11499, 33209, 591, 161550, 235275, 35910, 56974, 604, 1576, 235265, 235308, 235276, 235315, 95042, 4494, 1336, 1920, 235265, 50795, 235290, 14016, 235265, 2164, 235283, 50795, 235283, 50795, 235310, 235308, 235284, 235304, 235265, 5592, 892, 83102, 714, 97662, 235248, 235284, 235265, 235276, 80340, 32159, 235292, 206596, 20107, 32677, 235248, 235318, 235324, 235308, 235276, 235307, 892, 85734, 235318, 83102, 235248, 235318, 235324, 235318, 235304, 591, 16015, 235248, 235284, 235276, 235274, 235304, 1245, 235248, 235324, 235318, 235304, 235307, 42331, 235290, 17545, 5138, 38076, 4494, 1336, 1920, 235265, 50795, 235290, 14016, 235265, 2164, 235283, 50795, 235283, 50795, 235318, 235324, 235318, 235304, 235265, 5592, 21737, 4823, 235298, 235330, 105391, 235298, 235330, 235274, 235265, 32961, 172257, 82754, 25156, 235248, 235324, 235284, 2232, 235248, 235324, 235284, 11036, 235292, 235248, 235274, 235265, 235274, 235310, 235265, 235276, ...
#
#
# §§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§§
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 7
#       4 ##################
#       5 if regenerate:
#       6 #########################################################
# ----> 7     concepts_list = df2Graph(df, model=modelo)
#       8 #########################################################
#       9     dfg1 = graph2Df(concepts_list)
#
# Cell In[8], line 11, in df2Graph(dataframe, model)
#       8 results = results.reset_index(drop=True)
#      10 ## Flatten the list of lists to one single list of entities.
# ---> 11 concept_list = np.concatenate(results).ravel().tolist()
#      12 return concept_list
#
# ValueError: need at least one array to concatenate

# %% [markdown]
# ## Calculating contextual proximity

# %%
print(dfg1)
dfg2 = contextual_proximity(dfg1)

dfg2.to_csv(output_context_prox_file_with_path, sep=";", index=False)
dfg2.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(dfg1)
#       2 dfg2 = contextual_proximity(dfg1)
#       4 dfg2.to_csv(output_context_prox_file_with_path, sep=";", index=False)
#
# NameError: name 'dfg1' is not defined

# %% [markdown]
# ### Merge both the dataframes

# %% [markdown]
# dfg = pd.concat([dfg1, dfg2], axis=0)
# dfg = (
#     dfg.groupby(["node_1", "node_2"])
#     .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
#     .reset_index()
# )
# dfg

# %%
# Zusammenführen von dfg1 und dfg2
dfg = pd.concat([dfg1, dfg2], axis=0)

# Konvertieren von 'chunk_id' und 'edge' zu Strings, um den TypeError zu vermeiden
dfg['chunk_id'] = dfg['chunk_id'].astype(str)
dfg['edge'] = dfg['edge'].astype(str)

# Gruppierung und Aggregation
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)

dfg
# Out:
#                                     node_1  \
# 0    ['a concept from extracted ontology']
# 1    ['a concept from extracted ontology']
# 2                                ['a_sov']
# 3           ['anforderung', 'requirement']
# 4          ['betriebsstätte geburtshilfe']
# ..                                     ...
# 124                                    vzd
# 125                                    vzd
# 126                                    vzd
# 127                        zahnärztekammer
# 128                      öffentlich, stand
#
#                                                 node_2  \
# 0                                     ['implementing']
# 1          ['related concept from extracted ontology']
# 2                                        ['fachdaten']
# 3                           ['http statuscode', 'tls']
# 4    ['betriebsstätte gesundheits-, kranken- und al...
# ..                                                 ...
# 124                                           tabelle3
# 125                    tabelle6: tab_tuc_vzd_february2
# 126                     tabelle7: tab_tuc_vzd_gravity3
# 127                  kassenärztliche bundesvereinigung
# 128                                     dienst, nutzer
#
#                                               chunk_id  \
# 0    9fcisr6bafnrosicmbnbdfd7a6fleshrodfrudder,9fci...
# 1            9fcisr6bafnrosicmbnbdfd7a6fleshrodfrudder
# 2                                              context
# 3                                    1ffdc7d8cb0b8e4a5
# 4    fe8dfcbf7e6b53c,fe8dfcbf7e6b53c,fe8dfcbf7e6b53...
# ..                                                 ...
# 124  b1bd5a9cc9de1bfunkcrimpierrefe5d9cpubnre,b1bd5...
# 125  b1bd5a9cc9de1bfunkcrimpierrefe5d9cpubnre,b1bd5...
# 126  b1bd5a9cc9de1bfunkcrimpierrefe5d9cpubnre,b1bd5...
# 127                                                 cc
# 128                         public_status_base_service
#
#                                                   edge  count
# 0                                 contextual proximity      2
# 1    relationship between the two concepts, node_1 ...      4
# 2                                           one-to-one      4
# 3            ['related to', 'in one or two sentences']      4
# 4                                 contextual proximity      4
# ..                                                 ...    ...
# 124                               contextual proximity      3
# 125                               contextual proximity      3
# 126                               contextual proximity      6
# 127        Separate entities but related by profession      4
# 128  relationship between public status and related...      4
#
# [129 rows x 5 columns]

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (78,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  26
# [["['a concept from extracted ontology']", "['implementing']", "['muss']", "['related concept from extracted ontology']", "['schnittstelle']", "['testunterstützung']", "['vzd']"], ["['a_sov']", "['fachdaten']"], ["['add_vzd_features', 'add_external_id_extensions']", "['umsetzung soap', 'tip1-a_urfz']"], ["['add_vzd_features', 'tip1-a_urfz']", "['umsetzung add_directory_fa-attributes (soap)', 'add_external_id_extensions (soap)']"], ["['anforderung', 'requirement']", "['http statuscode', 'tls']"], ["['aufgebaut', 'built-up or established']", "['id.fd.tls-c', 'identifier of fd.tls-c protocol version']"], ["['betriebsstätte geburtshilfe']", "['betriebsstätte gesundheits-, kranken- und altenpflege']"], ["['betriebsstätte mobile einrichtung rettungsdienst']", "['bundeswehrapotheke']"], ["['case tuc_vzd_urgent4']", "['directorymaintenance.wsdl']", "['directorymaintenance.xsd']", "['dokumente']", "['modify_directory_entry']", "['webservice']"], ["['empfangen', 'empfangene']", "['rest requests', 'http statuscode']"], ["['empfangen', 'versendet']", "['fehler bei der verarbeitung des rest requests', 'http statuscode']"], ["['fad', 'framework for application development']", "['verbindung', 'connection']"], ["['fehlerfälle', 'http statuscode']", "['protokollspezifischen fehlermeldungen', 'rest requests']"], ['a concept from extracted ontology', 'a related concept from extracted ontology', 'geburtstag', 'geburtstage', 'geburtstage2', 'grunder2', 'id.zd.tls-s', 'tab_tuc_vzd_february2', 'tabelle', 'tabelle3', 'tabelle6: tab_tuc_vzd_february2', 'tabelle7: tab_tuc_vzd_gravity3', 'vzd'], ['an entry', 'deleted', 'valid certificates'], ['anforderung_id', 'requirement_id', 'rfc_id'], ['basisdaten', 'nicht gefunden'], ['betriebsstätte der kassenärztlichen bundesvereinigung', 'betriebsstätte einer zahnärztekammer'], ['bundeszahnärztekammer', 'kassenärztliche bundesvereinigung', 'zahnärztekammer'], ['certificate'], ['concept_id', 'condition_id', 'date_id', 'duration_id', 'entity_id', 'object_id', 'organization_id'], ['dienst, nutzer', 'öffentlich, stand'], ['fachdaten konnten nicht angelegt werden', 'fehler im verzeichnisdienst'], ['federal agency for technical education and information'], ['föhlerhaft ausgeführt', 'mouseout'], ['interface i_directory_query', 'operation search_directory']]

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                                  node    color  group
# 0               ['a concept from extracted ontology']  #63db57      1
# 1                                    ['implementing']  #63db57      1
# 2                                            ['muss']  #63db57      1
# 3         ['related concept from extracted ontology']  #63db57      1
# 4                                   ['schnittstelle']  #63db57      1
# ..                                                ...      ...    ...
# 73  federal agency for technical education and inf...  #db578c     24
# 74                              föhlerhaft ausgeführt  #a0db57     25
# 75                                           mouseout  #a0db57     25
# 76                        interface i_directory_query  #dbd957     26
# 77                         operation search_directory  #dbd957     26
#
# [78 rows x 3 columns]

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

#graph_output_directory = "./docs/index.html"

net = Network(
    notebook=True,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="800px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)

# net.show(graph_output_directory)
net.show_buttons(filter_=['physics'])
net.show("knowledge_graph.html")
# Out:
# knowledge_graph.html
#         <iframe
#             width="100%"
#             height="800px"
#             src="knowledge_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# DETAILED STEPS OF TERM PROXIMITY CALCULATION (same as function, only step by step to better understand the process)

# %%
## Melt the dataframe into a list of nodes
dfg_long = pd.melt(
    dfg1, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
)

# %%
dfg_long.tail(5)
# Out:
#                                      chunk_id variable  \
# 99   b1bd5a9cc9de1bfunkcrimpierrefe5d9cpubnre   node_2
# 100  b1bd5a9cc9de1bfunkcrimpierrefe5d9cpubnre   node_2
# 101  b1bd5a9cc9de1bfunkcrimpierrefe5d9cpubnre   node_2
# 102  b1bd5a9cc9de1bfunkcrimpierrefe5d9cpubnre   node_2
# 103  b1bd5a9cc9de1bfunkcrimpierrefe5d9cpubnre   node_2
#
#                                 node
# 99   tabelle6: tab_tuc_vzd_february2
# 100            tab_tuc_vzd_february2
# 101            tab_tuc_vzd_february2
# 102            tab_tuc_vzd_february2
# 103            tab_tuc_vzd_february2

# %%
dfg_long.drop(columns=["variable"], inplace=True)
# Self join with chunk id as the key will create a link between terms occuring in the same text chunk.

# %%
dfg_long.tail(5)
# Out:
#                                      chunk_id                             node
# 99   b1bd5a9cc9de1bfunkcrimpierrefe5d9cpubnre  tabelle6: tab_tuc_vzd_february2
# 100  b1bd5a9cc9de1bfunkcrimpierrefe5d9cpubnre            tab_tuc_vzd_february2
# 101  b1bd5a9cc9de1bfunkcrimpierrefe5d9cpubnre            tab_tuc_vzd_february2
# 102  b1bd5a9cc9de1bfunkcrimpierrefe5d9cpubnre            tab_tuc_vzd_february2
# 103  b1bd5a9cc9de1bfunkcrimpierrefe5d9cpubnre            tab_tuc_vzd_february2

# %%
dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))

# %%
dfg_wide.head()
# Out:
#                               chunk_id              node_1              node_2
# 0  6fe1f54e-7d8b-4dc9-b2c-e03d80a28687            an entry            an entry
# 1  6fe1f54e-7d8b-4dc9-b2c-e03d80a28687            an entry  valid certificates
# 2  6fe1f54e-7d8b-4dc9-b2c-e03d80a28687            an entry             deleted
# 3  6fe1f54e-7d8b-4dc9-b2c-e03d80a28687            an entry             deleted
# 4  6fe1f54e-7d8b-4dc9-b2c-e03d80a28687  valid certificates            an entry

# %%
# drop self loops
self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
dfgraph2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)

# %%
dfgraph2.head()
# Out:
#                               chunk_id              node_1              node_2
# 0  6fe1f54e-7d8b-4dc9-b2c-e03d80a28687            an entry  valid certificates
# 1  6fe1f54e-7d8b-4dc9-b2c-e03d80a28687            an entry             deleted
# 2  6fe1f54e-7d8b-4dc9-b2c-e03d80a28687            an entry             deleted
# 3  6fe1f54e-7d8b-4dc9-b2c-e03d80a28687  valid certificates            an entry
# 4  6fe1f54e-7d8b-4dc9-b2c-e03d80a28687  valid certificates             deleted

# %% [markdown]
# ## Group and count edges.
# dfgraph2 = (
#     dfgraph2.groupby(["node_1", "node_2"])
#     .agg({"chunk_id": [",".join, "count"]})
#     .reset_index()
# )

# %%
dfgraph2["chunk_id"] = dfgraph2["chunk_id"].astype(str)

# Gruppierung und Aggregation unter der Annahme, dass alle 'chunk_id' Werte nun Strings sind
dfgraph2 = (
    dfgraph2.groupby(["node_1", "node_2"])
    .agg(chunk_ids=("chunk_id", ",".join), count=("chunk_id", "count"))
    .reset_index()
)

# Umbenennen der Spalten für Klarheit (optional, basierend auf Ihrer Präferenz)
dfgraph2.columns = ["node_1", "node_2", "chunk_id", "count"]

# %%
dfgraph2.head()
# Out:
#                                   node_1  \
# 0  ['a concept from extracted ontology']
# 1  ['a concept from extracted ontology']
# 2  ['a concept from extracted ontology']
# 3  ['a concept from extracted ontology']
# 4  ['a concept from extracted ontology']
#
#                                         node_2  \
# 0                             ['implementing']
# 1                                     ['muss']
# 2  ['related concept from extracted ontology']
# 3                            ['schnittstelle']
# 4                        ['testunterstützung']
#
#                                             chunk_id  count
# 0  9fcisr6bafnrosicmbnbdfd7a6fleshrodfrudder,9fci...      2
# 1          9fcisr6bafnrosicmbnbdfd7a6fleshrodfrudder      1
# 2          9fcisr6bafnrosicmbnbdfd7a6fleshrodfrudder      1
# 3          9fcisr6bafnrosicmbnbdfd7a6fleshrodfrudder      1
# 4          9fcisr6bafnrosicmbnbdfd7a6fleshrodfrudder      1

# %%
dfgraph2.columns = ["node_1", "node_2", "chunk_id", "count"]
dfgraph2.replace("", np.nan, inplace=True)
dfgraph2.dropna(subset=["node_1", "node_2"], inplace=True)
# Drop edges with 1 count
dfgraph2 = dfg2[dfg2["count"] != 1]
dfgraph2["edge"] = "contextual proximity"

# %%
dfgraph2.head()
# Out:
#                                                node_1  \
# 0               ['a concept from extracted ontology']
# 13                    ['betriebsstätte geburtshilfe']
# 14  ['betriebsstätte gesundheits-, kranken- und al...
# 18                           ['case tuc_vzd_urgent4']
# 19                           ['case tuc_vzd_urgent4']
#
#                                                node_2  \
# 0                                    ['implementing']
# 13  ['betriebsstätte gesundheits-, kranken- und al...
# 14                    ['betriebsstätte geburtshilfe']
# 18                                      ['dokumente']
# 19                         ['modify_directory_entry']
#
#                                              chunk_id  count  \
# 0   9fcisr6bafnrosicmbnbdfd7a6fleshrodfrudder,9fci...      2
# 13  fe8dfcbf7e6b53c,fe8dfcbf7e6b53c,fe8dfcbf7e6b53...      4
# 14  fe8dfcbf7e6b53c,fe8dfcbf7e6b53c,fe8dfcbf7e6b53...      4
# 18  7a19d6f0-d58-4ea2-b73e-e8dfae1bda,7a19d6f0-d58...      2
# 19  7a19d6f0-d58-4ea2-b73e-e8dfae1bda,7a19d6f0-d58...      3
#
#                     edge
# 0   contextual proximity
# 13  contextual proximity
# 14  contextual proximity
# 18  contextual proximity
# 19  contextual proximity

# %%
dfgraph2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 94 entries, 0 to 291
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   node_1    94 non-null     object
#  1   node_2    94 non-null     object
#  2   chunk_id  94 non-null     object
#  3   count     94 non-null     int64
#  4   edge      94 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 4.4+ KB
